# %%
from spacr.plot import graph_importance
# %matplotlib inline

csvs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/results/feature_importance_compartment.csv']

settings = {'csvs':csvs,
           'grouping_column':'compartment',
           'data_column':'compartment_importance_sum',
           'graph_type':'jitter_bar',
            'save':False}

graph_importance(settings)

# %%
import pandas as pd
from spacr.plot import spacrGraph
import matplotlib.pyplot as plt
# %matplotlib inline

srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3/results/feature_importance_compartment.csv',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4/results/feature_importance_compartment.csv']

dfs = []
for path in srcs:
    dft = pd.read_csv(path)
    dfs.append(dft)

df = pd.concat(dfs)
display(df)

spacr_graph = spacrGraph(
    df=df,                                     
    grouping_column='compartment',                         
    data_column='compartment_importance_sum',         
    graph_type='jitter_bar',          
    graph_name='compartment',          
    summary_func='mean',                         
    colors=None,                                
    output_dir='/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/results',                              
    save=True,                       
    y_lim=None,                     
    error_bar_type='std',                       
    representation='object',
    theme='pastel',                    
)


# Create the plot
spacr_graph.create_plot()

# Get the figure object if needed
fig = spacr_graph.get_figure()
plt.show()

# %%
from spacr.submodules import analyze_endodyogeny
# %matplotlib inline

settings = {
    'src': '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1/',
    'tables': ['cell', 'nucleus', 'pathogen', 'cytoplasm'],
    'cell_types': ['Hela'],
    'cell_plate_metadata': None,
    'pathogen_types': ['nc', 'pc'],
    'pathogen_plate_metadata': [['c1'], ['c2']],
    'treatments': None,
    'treatment_plate_metadata': None,
    'min_area_bin': 500,
    'group_column': 'pathogen',
    'compartment': 'pathogen',
    'pathogen_limit': 1,
    'nuclei_limit': 1000,
    'level': 'well',
    'um_per_px':0.1,
    'max_bins':5,
    'save':False,
    'verbose': True}

# Run the analysis
chi2, p = analyze_endodyogeny(settings)
print(f"Chi-squared statistic: {chi2}, p-value: {p}")

# %%
from spacr.submodules import analyze_class_proportion
# %matplotlib inline

settings = {
    'src': '/nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1',
    'tables': ['cell', 'nucleus', 'pathogen', 'cytoplasm'],
    'cell_types': ['cm','infg'],
    'cell_plate_metadata': [['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c13', 'c14', 'c15', 'c16', 'c17', 'c18'],['c7', 'c8', 'c9', 'c10', 'c11', 'c12','c18', 'c19', 'c20', 'c21', 'c22', 'c23', 'c24']],
    'pathogen_types': ['nc', 'pc'],
    'pathogen_plate_metadata': [['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12'], ['c13', 'c14', 'c15', 'c16', 'c17', 'c18', 'c19', 'c20', 'c21', 'c22', 'c23', 'c24']],
    'treatments': ['ub','rnf'],
    'treatment_plate_metadata': [['c1', 'c2','c3', 'c7','c8','c9', 'c13','c14','c15','c19','c20','c21'],['c4','c5','c6','c10','c11','c12','c16','c17','c18','c22','c23','c24']],
    'group_column': 'condition',
    'class_column':'test',
    'pathogen_limit': 1000,
    'nuclei_limit': 1000,
    'level': 'well',
    'save':True,
    'verbose': True}

# Run the analysis
output = analyze_class_proportion(settings)
# Out:
#                          Key  \
# 0                        src
# 1                     tables
# 2                 cell_types
# 3        cell_plate_metadata
# 4             pathogen_types
# 5    pathogen_plate_metadata
# 6                 treatments
# 7   treatment_plate_metadata
# 8               group_column
# 9               class_column
# 10            pathogen_limit
# 11              nuclei_limit
# 12                     level
# 13                      save
# 14                   verbose
#
#                                                 Value
# 0   /nas_mnt/carruthers/yifan/Yifan_Einar screen/y...
# 1                [cell, nucleus, pathogen, cytoplasm]
# 2                                          [cm, infg]
# 3   [[c1, c2, c3, c4, c5, c6, c13, c14, c15, c16, ...
# 4                                            [nc, pc]
# 5   [[c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11...
# 6                                           [ub, rnf]
# 7   [[c1, c2, c3, c7, c8, c9, c13, c14, c15, c19, ...
# 8                                           condition
# 9                                                test
# 10                                               1000
# 11                                               1000
# 12                                               well
# 13                                               True
# 14                                               True
# cell: 30522
# nucleus: 40871
# pathogen: 55170
# cytoplasm: 30522
# png_list: 30522
# cells: 30522, cells grouped: 30522
# cytoplasms: 30522, cytoplasms grouped: 30522
# nucleus: 40871, nucleus grouped: 30522
# pathogens: 55170, pathogens grouped: 30522
# png_list: 30522, png_list grouped: 30522
# Added png_list columns: Index(['test'], dtype='object'), Index(['png_path'], dtype='object')
# Generated dataframe with: 793 columns and 30522 rows
# Chi-squared test statistic (raw data): 10386.3028
# p-value (raw data): 0.0000e+00
# Chi-squared results saved to /nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1/results/class_chi_squared_results.csv
# Annotated data saved to /nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1/results/class_chi_squared_data.csv
