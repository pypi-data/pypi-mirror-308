# %%
from piva.data_loader import DataloaderSIS as dl
from piva.working_procedures import get_step
from pathlib import Path
from os.path import getmtime
from datetime import datetime
import pandas as pd

# %%
# open files and save scans' names
files=[]
fnames=[]
date_and_time = []
path = '/Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/'
for fileobj in sorted(Path(path).iterdir(), key=getmtime):
    filename = str(fileobj)
    try:
        tmp_dl = dl()
        files.append(tmp_dl.load_data(filename))
        fnames.append(fileobj.name)
        date_and_time.append(datetime.fromtimestamp(getmtime(filename)))
        print(filename)
    except (ValueError,  OSError, NotImplementedError) as e:
        continue
# Out:
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0001.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0002.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0003.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0004.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0005.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0006.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0007.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/da_map_0008.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0000.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0001.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0002.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0003.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0004.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0005.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0006.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0007.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0008.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0009.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/band_map_0010.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_survey_0000.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_K_0000.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_Bi_0000.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_Ba_0000.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_K_0001.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_K_0002.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_Bi_0001.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/xps_Ba_0001.h5
# /Users/kaskadermike/ARPES_data_raw/BKBO/jul2023/s105_1/hv_scan_0000.h5

# %%
# collect the data that are actually interesting
temp=[]
hv=[]
grating=[]
polarization=[]
PE=[]
lens_mode=[]
anal_slit=[]
acq_mode=[]
DT=[]
x_pos=[]
y_pos=[]
z_pos=[]
theta=[]
phi=[]
tilt=[]
scan_type=[]
energy_range=[]
energy_step=[]
FE_slit=[]
V_slit=[]
comments=[]
for idx, file in enumerate(files):
    temp.append(file.temp)
    hv.append(file.hv)
    grating.append(' ')
    polarization.append(file.polarization)
    PE.append(file.PE)
    lens_mode.append(file.lens_mode)
    anal_slit.append(file.anal_slit)
    acq_mode.append(file.acq_mode)
    DT.append(file.DT)
    x_pos.append(file.x)
    y_pos.append(file.y)
    z_pos.append(file.z)
    theta.append(file.theta)
    scan_type.append(file.scan_type)
    phi.append(file.phi)
    tilt.append(file.tilt)
    energy_range.append('{:.2f} -> {:.2f}'.format(file.zscale.min(), file.zscale.max()))
    energy_step.append(get_step(file.zscale))
    FE_slit.append(file.FE)
    V_slit.append(file.exit_slit)
del files

# %%
# print what you want
d = {'scan name':fnames,
     'date and time':date_and_time,
     'T, K':temp,
     'hv, eV':hv,
     'PE, eV':PE,
     'PGM':grating,
     'polarization':polarization,
     'FE, mm':FE_slit,
     'V slit, $\mu$m':V_slit,
     'x, mm':x_pos,
     'y, mm':y_pos,
     'z, mm':z_pos,
     'theta, deg':theta,
     'phi, deg':phi,
     'tilt (step), deg':tilt,
     'scan type':scan_type,
     'lens mode':lens_mode,
     'anal slit':anal_slit,
     'E range, eV':energy_range,
     'E step, meV':energy_step,
     'acq mode':acq_mode,
     'DT, ms':DT
     # 'comments':comments
    }
df = pd.DataFrame(data=d).sort_values(by='date and time')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
df
# Out:
#              scan name       date and time      T, K      hv, eV  PE, eV PGM  \
# 0      da_map_0001.zip 2023-07-01 20:56:56       NaN    0.000000    20.0
# 1      da_map_0002.zip 2023-07-01 21:26:41       NaN    0.000000    20.0
# 2      da_map_0003.zip 2023-07-01 21:46:18       NaN    0.000000    20.0
# 3      da_map_0004.zip 2023-07-01 22:01:23       NaN    0.000000    20.0
# 4      da_map_0005.zip 2023-07-01 22:15:01       NaN    0.000000    20.0
# 5      da_map_0006.zip 2023-07-01 22:28:27       NaN    0.000000    20.0
# 6      da_map_0007.zip 2023-07-01 22:42:08       NaN    0.000000    20.0
# 7      da_map_0008.zip 2023-07-01 23:03:33       NaN    0.000000    20.0
# 8     band_map_0000.h5 2023-07-01 23:15:21  210.5670   73.999829    20.0
# 9     band_map_0001.h5 2023-07-01 23:26:11  210.9540   73.997608    20.0
# 10    band_map_0002.h5 2023-07-01 23:36:56  212.2850   73.999422    20.0
# 11    band_map_0003.h5 2023-07-02 00:21:44   97.6616   73.998863    20.0
# 12    band_map_0004.h5 2023-07-02 00:31:35   80.0708   73.997790    20.0
# 13    band_map_0005.h5 2023-07-02 00:43:21   82.4920   73.997701    20.0
# 14    band_map_0006.h5 2023-07-02 01:04:30   44.9573   73.998142    20.0
# 15    band_map_0007.h5 2023-07-02 01:17:58   43.7199   73.998662    20.0
# 16    band_map_0008.h5 2023-07-02 01:30:47   41.5643   73.999219    20.0
# 17    band_map_0009.h5 2023-07-02 01:57:21   10.7503   74.000353    20.0
# 18    band_map_0010.h5 2023-07-02 02:04:24   10.5830   73.997929    20.0
# 19  xps_survey_0000.h5 2023-07-02 02:14:57   10.4424  399.996253    20.0
# 20       xps_K_0000.h5 2023-07-02 02:26:07   10.4063  389.998150    20.0
# 21      xps_Bi_0000.h5 2023-07-02 02:31:26   10.3930  256.996586    20.0
# 22      xps_Ba_0000.h5 2023-07-02 02:35:39   10.3083  190.002262    20.0
# 23       xps_K_0001.h5 2023-07-02 02:39:51    0.0000  389.994408    20.0
# 24       xps_K_0002.h5 2023-07-02 02:46:04   10.1020  389.996692    20.0
# 25      xps_Bi_0001.h5 2023-07-02 02:51:24   10.0716  257.001513    20.0
# 26      xps_Ba_0001.h5 2023-07-02 02:55:37   10.0006  189.998033    20.0
# 27     hv_scan_0000.h5 2023-07-02 10:07:39   13.7905   29.999906    20.0
#
#    polarization  FE, mm  V slit, $\mu$m    x, mm    y, mm    z, mm  \
# 0          None     NaN             NaN      NaN      NaN      NaN
# 1          None     NaN             NaN      NaN      NaN      NaN
# 2          None     NaN             NaN      NaN      NaN      NaN
# 3          None     NaN             NaN      NaN      NaN      NaN
# 4          None     NaN             NaN      NaN      NaN      NaN
# 5          None     NaN             NaN      NaN      NaN      NaN
# 6          None     NaN             NaN      NaN      NaN      NaN
# 7          None     NaN             NaN      NaN      NaN      NaN
# 8           LHQ     2.0            15.0  0.80595  0.05265  0.49445
# 9           LHQ     2.0            15.0  0.80595  0.05265  0.49445
# 10          LHQ     2.0            15.0  0.80595  0.05265  0.49445
# 11          LHQ     2.0            15.0  0.80595  0.05265  0.49445
# 12          LHQ     2.0            15.0  0.80595  0.05265  0.49445
# 13          LHQ     2.0            15.0  0.80595  0.05265  0.53420
# 14          LHQ     2.0            15.0  0.80110  0.05265  0.70875
# 15          LHQ     2.0            15.0  0.80110  0.05265  0.40930
# 16          LHQ     2.0            15.0  0.80110  0.05265  0.40930
# 17          LHQ     2.0            15.0  0.80110  0.05265  0.55280
# 18          LHQ     2.0            15.0  0.80110  0.05265  0.55280
# 19           LH     2.0            15.0  0.80110  0.05265  0.55280
# 20           LH     2.0            15.0  0.80110  0.05265  0.55280
# 21           LH     2.0            15.0  0.80110  0.05265  0.55280
# 22           LH     2.0            15.0  0.80110  0.05265  0.55280
# 23           LH     0.0             0.0  0.00000  0.00000  0.00000
# 24           LH     2.0            50.0  0.80110  0.05265  0.55280
# 25           LH     2.0            50.0  0.80110  0.05265  0.55280
# 26           LH     2.0            50.0  0.80110  0.05265  0.55280
# 27          LHQ     2.0            15.0  0.80110  0.05265  0.45305
#
#     theta, deg   phi, deg  tilt (step), deg scan type lens mode anal slit  \
# 0          NaN        NaN               NaN   DA scan  DA30L_01      None
# 1          NaN        NaN               NaN   DA scan  DA30L_01      None
# 2          NaN        NaN               NaN   DA scan  DA30L_01      None
# 3          NaN        NaN               NaN   DA scan  DA30L_01      None
# 4          NaN        NaN               NaN   DA scan  DA30L_01      None
# 5          NaN        NaN               NaN   DA scan  DA30L_01      None
# 6          NaN        NaN               NaN   DA scan  DA30L_01      None
# 7          NaN        NaN               NaN   DA scan  DA30L_01      None
# 8    -8.996292  53.499558          2.425764       cut   A30L_01      None
# 9    -8.996292  53.499558          2.425764       cut   A30L_01      None
# 10   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 11   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 12   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 13   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 14   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 15   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 16   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 17   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 18   -8.996292  53.499558          2.425764       cut   A30L_01      None
# 19   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 20   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 21   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 22   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 23    0.000000   0.000000          0.000000       cut   A30L_08      None
# 24   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 25   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 26   -8.996292  53.499558          2.425764       cut   A30L_08      None
# 27   -8.996292  53.499558          2.460920   hv scan   A30L_01      None
#
#            E range, eV  E step, meV acq mode  DT, ms
# 0     114.57 -> 115.76     0.001423    Fixed   11905
# 1     114.57 -> 115.76     0.001423    Fixed   11905
# 2     114.57 -> 115.76     0.001423    Fixed   11905
# 3     114.57 -> 115.76     0.001423    Fixed   11905
# 4     114.57 -> 115.76     0.001423    Fixed   11905
# 5     114.57 -> 115.76     0.001423    Fixed   11905
# 6     114.57 -> 115.76     0.001423    Fixed   11905
# 7     114.57 -> 115.76     0.001423    Fixed   11905
# 8        -1.49 -> 0.02     0.001945    Swept      63
# 9        -1.49 -> 0.15     0.001944    Swept      63
# 10       -1.50 -> 0.15     0.001944    Swept      63
# 11       -1.50 -> 0.15     0.001944    Swept      63
# 12       -1.50 -> 0.15     0.001944    Swept      63
# 13       -1.50 -> 0.15     0.001944    Swept      63
# 14       -1.50 -> 0.15     0.001944    Swept      63
# 15       -1.50 -> 0.15     0.001944    Swept      63
# 16       -1.50 -> 0.15     0.001944    Swept      63
# 17       -1.50 -> 0.15     0.001944    Swept      63
# 18       -1.50 -> 0.15     0.001944    Swept      63
# 19     50.00 -> 350.07     0.051951    Swept      32
# 20  -310.01 -> -282.99     0.010524    Swept      79
# 21  -170.01 -> -149.99     0.010525    Swept      79
# 22    -96.00 -> -79.99     0.010526    Swept      79
# 23  -310.01 -> -282.99     0.010524    Swept      79
# 24  -310.01 -> -282.99     0.010524    Swept      79
# 25  -170.01 -> -149.99     0.010525    Swept      79
# 26    -96.00 -> -79.99     0.010526    Swept      79
# 27       -1.51 -> 0.14     0.001422    Swept      40
