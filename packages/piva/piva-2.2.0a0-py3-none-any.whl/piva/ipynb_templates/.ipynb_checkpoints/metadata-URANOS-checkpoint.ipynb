# %%
from piva.data_loader import DataloaderURANOS as dl
from piva.working_procedures import get_step
from pathlib import Path
from os.path import getmtime
from datetime import datetime
import pandas as pd

# %%
# open files and save scans' names
files=[]
fnames=[]
date_and_time = []
path = '/Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/'
for fileobj in sorted(Path(path).iterdir(), key=getmtime):
    filename = str(fileobj)
    try:
        tmp_dl = dl()
        files.append(tmp_dl.load_data(filename))
        fnames.append(fileobj.name)
        date_and_time.append(datetime.fromtimestamp(getmtime(filename)))
        print(filename)
    except (ValueError,  OSError, NotImplementedError) as e:
        continue
# Out:
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0001.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0002.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0003.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0005.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0006.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0007.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0008.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0009.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0010.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0011.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0012.pxt
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0012.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0008.zip
# /Users/kaskadermike/ARPES_data_raw/BKBO/apr2023/s104/s104_0004.zip

# %%
# collect the data that are actually interesting
temp=[]
hv=[]
grating=[]
polarization=[]
PE=[]
lens_mode=[]
anal_slit=[]
acq_mode=[]
DT=[]
x_pos=[]
y_pos=[]
z_pos=[]
theta=[]
phi=[]
tilt=[]
scan_type=[]
energy_range=[]
energy_step=[]
FE_slit=[]
V_slit=[]
comments=[]
for idx, file in enumerate(files):
    temp.append('-')
    hv.append("{:.2f}".format(file.hv))
    grating.append('-')
    polarization.append('-')
    PE.append(int(file.PE))
    lens_mode.append(file.lens_mode)
    anal_slit.append('-')
    acq_mode.append(file.acq_mode)
    DT.append(file.DT)
    x_pos.append("{:.2f}".format(file.x))
    y_pos.append("{:.2f}".format(file.y))
    z_pos.append("{:.2f}".format(file.z))
    theta.append("{:.2f}".format(file.theta))
    tilt.append("{:.2f}".format(file.tilt))
    phi.append('-')
    scan_type.append(file.scan_type)
    e_start = file.zscale[0]
    e_nsteps = file.zscale.size
    e_stop = file.zscale[-1]
    energy_range.append('{:.2f} -> {:.2f}'.format(e_start, e_stop))
    energy_step.append('{:.3}'.format(get_step(file.zscale) * 1000))
    FE_slit.append('-')
    V_slit.append('-')
del files

# %%
# print what you want
d = {'scan name':fnames,
     'date and time':date_and_time,
     'T, K':temp,
     'hv, eV':hv,
     'PE, eV':PE,
     'PGM':grating,
     'polarization':polarization,
     'FE, mm':FE_slit,
     'V slit, $\mu$m':V_slit,
     'x, mm':x_pos,
     'y, mm':y_pos,
     'z, mm':z_pos,
     'theta, deg':theta,
     'phi, deg':phi,
     'tilt (step), deg':tilt,
     'scan type':scan_type,
     'lens mode':lens_mode,
     'anal slit':anal_slit,
     'E range, eV':energy_range,
     'E step, meV':energy_step,
     'acq mode':acq_mode,
     'DT, ms':DT
    }
df = pd.DataFrame(data=d)#.sort_values(by='date and time')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
df
# Out:
#         scan name           date and time T, K hv, eV  PE, eV PGM  \
# 0   s104_0001.zip 2023-04-19 19:28:42.000    -  73.99      20   -
# 1   s104_0002.zip 2023-04-19 19:32:39.480    -  73.99      20   -
# 2   s104_0003.zip 2023-04-19 19:46:26.770    -  73.99      20   -
# 3   s104_0005.pxt 2023-04-20 10:33:03.610    -  73.99      20   -
# 4   s104_0006.pxt 2023-04-20 10:33:03.840    -  73.99      20   -
# 5   s104_0007.pxt 2023-04-20 10:33:05.610    -  73.99      20   -
# 6   s104_0008.pxt 2023-04-20 10:33:07.690    -  73.99      20   -
# 7   s104_0009.pxt 2023-04-20 10:33:09.730    -  73.99      20   -
# 8   s104_0010.pxt 2023-04-20 10:33:12.190    -  73.99      10   -
# 9   s104_0011.pxt 2023-04-20 10:33:15.300    -  73.99      10   -
# 10  s104_0012.pxt 2023-04-20 10:33:17.490    -  73.99      20   -
# 11  s104_0012.zip 2023-04-20 10:34:02.930    -  73.99      20   -
# 12  s104_0008.zip 2023-04-20 10:34:03.630    -  73.99      20   -
# 13  s104_0004.zip 2023-04-20 10:34:30.940    -  73.99      20   -
#
#    polarization FE, mm V slit, $\mu$m x, mm  y, mm z, mm theta, deg phi, deg  \
# 0             -      -              -  0.60  -2.65  1.25     181.50        -
# 1             -      -              -  0.60  -2.65  1.25     191.50        -
# 2             -      -              -  0.60  -2.55  1.21     176.50        -
# 3             -      -              -  0.60  -2.55  1.10     173.50        -
# 4             -      -              -  0.60  -2.55  1.10     173.50        -
# 5             -      -              -  0.60  -2.55  1.10     173.50        -
# 6             -      -              -  0.60  -2.55  1.10     173.50        -
# 7             -      -              -  0.60  -2.55  1.10     173.50        -
# 8             -      -              -  0.60  -2.55  1.10     173.50        -
# 9             -      -              -  0.60  -2.55  1.10     173.50        -
# 10            -      -              -  0.60  -2.55  1.10     173.50        -
# 11            -      -              -  0.60  -2.55  1.10     173.50        -
# 12            -      -              -  0.60  -2.55  1.10     173.50        -
# 13            -      -              -  0.60  -2.55  1.10     173.50        -
#
#    tilt (step), deg scan type lens mode anal slit     E range, eV E step, meV  \
# 0            -93.00   DA scan  DA30L_01         -  67.99 -> 69.40        1.47
# 1            -93.00   DA scan  DA30L_01         -  67.99 -> 69.40        1.47
# 2            -95.00   DA scan  DA30L_01         -  67.99 -> 69.40        1.47
# 3            -84.00       cut  DA30L_01         -  64.30 -> 69.31        15.0
# 4            -84.00       cut  DA30L_01         -  64.30 -> 69.82        15.0
# 5            -83.00       cut  DA30L_01         -  64.30 -> 69.82        15.0
# 6            -83.00       cut  DA30L_01         -  67.80 -> 69.80        5.01
# 7            -83.00       cut  DA30L_01         -  64.30 -> 69.82        15.0
# 8            -83.00       cut  DA30L_01         -  67.50 -> 69.50        5.01
# 9            -83.00       cut  DA30L_01         -  67.50 -> 69.50        5.01
# 10           -83.00       cut  DA30L_01         -  67.50 -> 69.50        5.01
# 11           -83.00   DA scan  DA30L_01         -  67.50 -> 69.51        10.0
# 12           -83.00   DA scan  DA30L_01         -  67.80 -> 69.81        10.0
# 13           -85.00   DA scan  DA30L_01         -  67.99 -> 69.40        1.47
#
#    acq mode  DT, ms
# 0     Fixed    4412
# 1     Fixed    2941
# 2     Fixed    2941
# 3     Swept     235
# 4     Swept     235
# 5     Swept     235
# 6     Swept     235
# 7     Swept     235
# 8     Swept     235
# 9     Swept     235
# 10    Swept     235
# 11    Swept     294
# 12    Swept     294
# 13    Fixed    4412
