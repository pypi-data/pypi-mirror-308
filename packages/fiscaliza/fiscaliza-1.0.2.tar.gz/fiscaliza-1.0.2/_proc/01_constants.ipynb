# %% [raw]
# ---
# description: "M\xF3dulo com as constantes do projeto"
# output-file: constants.html
# title: Constants
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
