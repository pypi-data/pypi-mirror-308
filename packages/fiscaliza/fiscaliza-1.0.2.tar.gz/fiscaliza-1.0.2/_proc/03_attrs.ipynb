# %% [raw]
# ---
# description: "Rela\xE7\xE3o dos campos contidos nas diferentes Inspe\xE7\xF5es do\
#   \ Fiscaliza com as inst\xE2ncias de classe que os representam."
# output-file: attrs.html
# title: Attributes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
